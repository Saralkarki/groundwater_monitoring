# %%
import pandas as pd

# %%
df = pd.read_excel('data/preloaded_data/updated_well_data.xlsx')

# %%
location = df['Location'].tolist()

# %%
well_no = df['well_no'].tolist()

# %%
df_banke_stw = df[df['district']== 'Banke']

# %%
df
# Out:
#     S.No.           Well No.     well_no         Location  Longitude  \
# 0       1     1-045/46(BK)1     bk-sw-01     Rohini Khola  81.516600
# 1       2     1-045/46(BK)2     bk-sw-02         Jabdhawa  81.644302
# 2       3     1-045/46(BK)3     bk-sw-03         Banktuwa  81.626709
# 3       4     1-045/46(BK)4     bk-sw-04         Channawa  81.624592
# 4       5     1-045/46(BK)5   bk-sw-05_1          Thapawa  81.583815
# 5       6     1-045/46(BK)6   bk-sw-06_1         Piprahwa  81.659897
# 6       7     1-045/46(BK)7   bk-sw-07_1           Bhujai  81.632117
# 7       8     1-045/46(BK)8   bk-sw-08_1            Birta  81.660374
# 8       9     1-045/46(BK)9   bk-sw-09_1      Sikhanpurwa  81.667285
# 9      10    1-045/46(BK)10   bk-sw-10_1        Kharaicha  81.719469
# 10     11    1-045/46(BK)11   bk-sw-11_1         Jaishpur  81.601250
# 11     17    1-045/46(BK)17   bk-sw-17_1           D-gaon  81.611090
# 12     18    1-045/46(BK)18   bk-sw-18_1      Kalhansgaon  81.552002
# 13     19    1-045/46(BK)19   bk-sw-19_1          Gaughat  81.555843
# 14     20    1-045/46(BK)20   bk-sw-20_1      Mahadevpuri  81.756058
# 15     24        NISP-STW/1   bk-sw-24_1  Office compound  81.645010
# 16     25    NISP-INV-STW/8   bk-sw-25_1      Kajurakurda  81.798200
# 17     26    NISP-INV-STW/10    bk-sw-26      Banjaregaon  81.593260
# 18     27    NISP-INV-STW/11    bk-sw-27        Ramapurwa  81.595560
# 19     28                NaN    bk-sw-28        Jaogagaun        NaN
# 20     29                NaN    bk-sw-29       Baldipurwa        NaN
# 21     30                NaN    bk-sw-30       Harbaldoli        NaN
# 22     28    1-045\46(B\D)1     bd-sw-01          Bertani        NaN
# 23     29    2-045\46(B\D)2     bd-sw-02      Bakharikurd        NaN
# 24     30    3-045\46(B\D)3     bd-sw-03      Mainapokhar        NaN
# 25     31    4-045\46(B\D)4     bd-sw-04           Bangai        NaN
# 26     32    5-045\46(B\D)5     bd-sw-05         Bhaisahi        NaN
# 27     33    6-045\46(B\D)6     bd-sw-06       Rain Nagar        NaN
# 28     34    7-045\46(B\D)7     bd-sw-07     Megara Gadhi        NaN
# 29     35    8-045\46(B\D)8     bd-sw-08             Auri        NaN
# 30     36    9-045\46(B\D)9     bd-sw-09        Khairapur        NaN
# 31     37  10-045\46(B\D)10     bd-sw-10          Padnaha        NaN
# 32     38  11-045\46(B\D)11     bd-sw-11       Baniyabhar        NaN
# 33     39  12-045\46(B\D)12     bd-sw-12          Taratal        NaN
# 34     40  13-045\46(B\D)13     bd-sw-13        Madhubhan        NaN
# 35     41  14-045\46(B\D)14     bd-sw-14          Begnaha        NaN
# 36     42  15-045\46(B\D)15     bd-sw-15        Bhurigaon        NaN
# 37     43  16-045\46(B\D)16     bd-sw-16          Newlpur        NaN
# 38     44  17-045\46(B\D)17     bd-sw-17      Thakurdwaar        NaN
# 39     45    NISP\INV\STW-5     bd-sw-18        Shoharawa        NaN
# 40     46              n.a.     bd-sw-19       Bhawanipur        NaN
# 41     47    NISP\INV\STW-6     bd-sw-20        Shoharawa        NaN
# 42     48              na.a     bd-sw-21            Belwa        NaN
# 43     49              n.a.     bd-sw-22            Belwa        NaN
# 44     50              n.a.     bd-sw-23      Janaki Tool        NaN
#
#      Latitude district
# 0   28.122310    Banke
# 1   28.255733    Banke
# 2   28.210682    Banke
# 3   28.197151    Banke
# 4   28.193269    Banke
# 5   28.139214    Banke
# 6   28.090600    Banke
# 7   28.050749    Banke
# 8   28.016413    Banke
# 9   27.986361    Banke
# 10  28.031161    Banke
# 11  28.152078    Banke
# 12  28.148718    Banke
# 13  28.103568    Banke
# 14  28.201453    Banke
# 15  28.081250    Banke
# 16  28.143030    Banke
# 17  28.078070    Banke
# 18  28.082760    Banke
# 19        NaN    Banke
# 20        NaN    Banke
# 21        NaN    Banke
# 22        NaN  Bardiya
# 23        NaN  Bardiya
# 24        NaN  Bardiya
# 25        NaN  Bardiya
# 26        NaN  Bardiya
# 27        NaN  Bardiya
# 28        NaN  Bardiya
# 29        NaN  Bardiya
# 30        NaN  Bardiya
# 31        NaN  Bardiya
# 32        NaN  Bardiya
# 33        NaN  Bardiya
# 34        NaN  Bardiya
# 35        NaN  Bardiya
# 36        NaN  Bardiya
# 37        NaN  Bardiya
# 38        NaN  Bardiya
# 39        NaN  Bardiya
# 40        NaN  Bardiya
# 41        NaN  Bardiya
# 42        NaN  Bardiya
# 43        NaN  Bardiya
# 44        NaN  Bardiya

# %%
[{'label': i, 'value': j} for i,j in zip(location,well_no)]
# Out:
# [{'label': 'Rohini Khola', 'value': 'bk-sw-01'},
#  {'label': 'Jabdhawa', 'value': 'bk-sw-02'},
#  {'label': 'Banktuwa', 'value': 'bk-sw-03'},
#  {'label': 'Channawa', 'value': 'bk-sw-04'},
#  {'label': 'Thapawa', 'value': 'bk-sw-05_1'},
#  {'label': 'Piprahwa', 'value': 'bk-sw-06_1'},
#  {'label': 'Bhujai', 'value': 'bk-sw-07_1'},
#  {'label': 'Birta', 'value': 'bk-sw-08_1'},
#  {'label': 'Sikhanpurwa', 'value': 'bk-sw-09_1'},
#  {'label': 'Kharaicha', 'value': 'bk-sw-10_1'},
#  {'label': 'Jaishpur', 'value': 'bk-sw-11_1'},
#  {'label': 'D-gaon', 'value': 'bk-sw-17_1'},
#  {'label': 'Kalhansgaon', 'value': 'bk-sw-18_1'},
#  {'label': 'Gaughat', 'value': 'bk-sw-19_1'},
#  {'label': 'Mahadevpuri', 'value': 'bk-sw-20_1'},
#  {'label': 'Office compound', 'value': 'bk-sw-24_1'},
#  {'label': 'Kajurakurda', 'value': 'bk-sw-25_1'},
#  {'label': 'Banjaregaon', 'value': 'bk-sw-26'},
#  {'label': 'Ramapurwa', 'value': 'bk-sw-27'},
#  {'label': 'Jaogagaun', 'value': 'bk-sw-28'},
#  {'label': 'Baldipurwa', 'value': 'bk-sw-29'},
#  {'label': 'Harbaldoli', 'value': 'bk-sw-30'},
#  {'label': 'Bertani', 'value': 'bd-sw-01'},
#  {'label': 'Bakharikurd', 'value': 'bd-sw-02'},
#  {'label': 'Mainapokhar', 'value': 'bd-sw-03'},
#  {'label': 'Bangai', 'value': 'bd-sw-04'},
#  {'label': 'Bhaisahi', 'value': 'bd-sw-05'},
#  {'label': 'Rain Nagar', 'value': 'bd-sw-06'},
#  {'label': 'Megara Gadhi', 'value': 'bd-sw-07'},
#  {'label': 'Auri', 'value': 'bd-sw-08'},
#  {'label': 'Khairapur', 'value': 'bd-sw-09'},
#  {'label': 'Padnaha', 'value': 'bd-sw-10'},
#  {'label': 'Baniyabhar', 'value': 'bd-sw-11'},
#  {'label': 'Taratal', 'value': 'bd-sw-12'},
#  {'label': 'Madhubhan', 'value': 'bd-sw-13'},
#  {'label': 'Begnaha', 'value': 'bd-sw-14'},
#  {'label': 'Bhurigaon', 'value': 'bd-sw-15'},
#  {'label': 'Newlpur', 'value': 'bd-sw-16'},
#  {'label': 'Thakurdwaar', 'value': 'bd-sw-17'},
#  {'label': 'Shoharawa', 'value': 'bd-sw-18'},
#  {'label': 'Bhawanipur', 'value': 'bd-sw-19'},
#  {'label': 'Shoharawa', 'value': 'bd-sw-20'},
#  {'label': 'Belwa', 'value': 'bd-sw-21'},
#  {'label': 'Belwa', 'value': 'bd-sw-22'},
#  {'label': 'Janaki Tool', 'value': 'bd-sw-23'}]
