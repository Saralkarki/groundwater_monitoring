# %%
import requests
from requests.auth import HTTPBasicAuth
import pandas as pd
import time, sched

import dash_html_components as html
import dash_core_components as dcc

import calendar
from urllib.parse import quote as urlquote

url= "https://kc.humanitarianresponse.info/api/v1/data/669773.json"
auth = HTTPBasicAuth('gw_monitoring', 'gwmonitor@2020')

import base64
import io
import datetime
import dash_table
import os
from os import path



# files = {'filename': open('filename.txt','rb')}
def download_data():
    download = requests.get(url, auth=auth )
    # col_names = ['Enumerator Name','Geo_location','Municipality','village_name','ward','well_type','well_no_stw','well_no_dtw','gw_level','Height_of_measurement','measurement_unit',"Notes"]
    # df = pd.read_csv('updated_data.csv')  
    j = requests.get(url, auth=auth )
    df_json = j.json()
    gw_df = pd.DataFrame.from_dict(df_json)
#     print(gw_df.columns)
#     print(len(gw_df.columns))  
    # 'sw_bk_well_no','bk_dw_no','well_no_sw_bardiya','well_no_dw_bardiya',
    if not 'Main_group/location_details/sw_bk_well_no' in gw_df.columns:
        #     print("NO cols_1")
            gw_df['sw_bk_well_no'] = '' 
    if not 'Main_group/location_details/bk_dw_no' in gw_df.columns:
        #     print("NO cols_2")
            gw_df['bk_dw_no'] = '' 
    
    if not 'Main_group/location_details/well_no_sw_bardiya' in gw_df.columns:
        #     print("NO cols_3")
            gw_df['well_no_sw_bardiya'] = '' 
    
    if not 'Main_group/location_details/well_no_dw_bardiya' in gw_df.columns:
            gw_df['well_no_dw_bardiya'] = '' 
        #     print("NO cols_4")
#     print(len(gw_df.columns))   
#     print(gw_df.columns)       
    # gw_df = pd.read_json(download.text)   
    if len(gw_df.columns) != 36:
        #     return html.Div([html.H1("ERROR: With fetching the data. Please check later")])
            df = pd.DataFrame()
        #     df = pd.read_csv('updated_data.csv')  
            print("ERROR")
    else:
        gw_df.columns = ['_notes',
       'Measurement_of_tape_ent_point_MP_in_m', '_tags',
       '_xform_id_string', 'meta/instanceID',
       'gw_level_from_mp', 'end',
       'gw_level',
       'Well_photo_Use_the_ed_measurement_point',
       'mp_in_m', 'start', '_attachments', '_version_',
       '_status', '__version__', 'today',
       'sw_bk_well_no',
       'Enumerator Name',
       'Geo_location', '_validation_status',
       '_uuid', 'well_type', 'formhub/uuid',
       'District', '_submission_time',
       '_geolocation', '_submitted_by',
       'wet_point_measruement_on_tape', 'deviceid',
       'measurement_point_cm', '_id',
       'Notes',
       'Audio_Notes',
       'well_no_sw_bardiya', 'bk_dw_no',
       'well_no_dw_bardiya']
        all_cols = ['Enumerator Name','Geo_location','District',
        'well_type','sw_bk_well_no','bk_dw_no','well_no_sw_bardiya','well_no_dw_bardiya','measurement_point_cm',
        'Measurement_of_tape_ent_point_MP_in_m', 'wet_point_measruement_on_tape','gw_level',
        'Notes','today','Audio_Notes']

        # print(gw_df)
        df = pd.DataFrame()
        
        for cols in all_cols:
                df[cols] = gw_df[cols]
        # df = gw_df.copy()  
        # print(df) 
        # df = df.sort_values(by='today')
        # print(df)
        # df['Enumerator']
            # print(gw_df[i])   
        df['well_no'] = (df['sw_bk_well_no'].combine_first(df['bk_dw_no']).combine_first(df['well_no_sw_bardiya']).combine_first(df['well_no_dw_bardiya']))
        ## onvertt he today data to date    
        df['today'] = pd.to_datetime(df['today'])
        df['Month'] = df['today'].dt.month
        # print(df['Month'])
        df['Month'] = df['Month'].apply(lambda x: calendar.month_abbr[x])   
        df.to_csv('updated_data.csv')
    return df 

gw_df = download_data()


### Data to map the values
def map_data(well_number):
        df = pd.read_csv('updated_data.csv')
        cols = ['well_no','Month','gw_level']
        df = df[cols]
        x = df[df['well_no'].isin([well_number])]
        # print(x)
        return x


#banke SW data


banke_sw = gw_df[(gw_df['District']=="Banke") & (gw_df['well_type'] == 'sw')]
banke_sw= banke_sw[['Enumerator Name','Geo_location','District',
        'well_type','sw_bk_well_no','gw_level',
        'measurement_point_cm',
        'Measurement_of_tape_ent_point_MP_in_m',
        'Notes']]




banke_dw = gw_df[(gw_df['District']=="Banke") & (gw_df['well_type'] == 'dt')]
banke_dw = banke_dw[['Enumerator Name','Geo_location','District',
        'well_type','bk_dw_no','gw_level',
        'measurement_point_cm',
        'Measurement_of_tape_ent_point_MP_in_m',
        'Notes']]



bardiya_sw = gw_df[(gw_df['District']=="Bardiya") & (gw_df['well_type'] == 'sw')]


bardiya_sw = bardiya_sw[['Enumerator Name','Geo_location','District','well_type','well_no_sw_bardiya','gw_level',
        'measurement_point_cm','Measurement_of_tape_ent_point_MP_in_m',
        'Notes']]

    


bardiya_dw = gw_df[(gw_df['District']=="Bardiya") & (gw_df['well_type'] == 'dt')]
bardiya_dw = bardiya_dw[['Enumerator Name','Geo_location','District',
        'well_type','well_no_dw_bardiya','gw_level',
        'measurement_point_cm',
        'Measurement_of_tape_ent_point_MP_in_m',
        'Notes']]



# print(gw_df)
print("JOB DONE")
# UPLOAD_DIRECTORY = "data/uploaded_data"

# if not os.path.exists(UPLOAD_DIRECTORY):
#     os.makedirs(UPLOAD_DIRECTORY)

def save_file(name, content):
        """Decode and store a file uploaded with Plotly Dash."""
       
        try:
                if 'csv' in name:
                        data = content.encode("utf8").split(b";base64,")[1]
                        with open(os.path.join(UPLOAD_DIRECTORY, name), "wb") as fp:
                                fp.write(base64.decodebytes(data))

                        df = pd.read_csv(name, skiprows=[1])
                        return html.Div(['There was an error processing this file.'])
                        # print(df)
        except Exception as e:
                print(e)
                return html.Div(['There was an error processing this file.'])

def parse_contents(contents, filename, date):
    content_type, content_string = contents.split(',')
    data = contents.encode("utf8").split(b";base64,")[1]    
    decoded = base64.b64decode(content_string)
    try:
        
        if 'csv' in filename:
            if path.exists(filename):
            # Assume that the user uploaded a CSV file
                df = pd.read_csv(io.StringIO(decoded.decode('utf-8')), skiprows=[0])
                # df.insert(loc=0, column='', value='')
                df.to_csv(filename, mode='a', header=False)
            # with open(os.path.join(UPLOAD_DIRECTORY, filename), "wb") as fp:
            #         fp.write(base64.decodebytes(data))
        else:
                return html.Div(['There was an error processing this file. Please check if it is a CSV file'])
    except Exception as e:
        print(e)

    return html.Div([
        html.H5(f"{filename} has been uploaded"),
        html.H6(datetime.datetime.fromtimestamp(date)),

        dash_table.DataTable(
            data=df.to_dict('records'),
            columns=[{'name': i, 'id': i} for i in df.columns]
        ),

        html.Hr(),  # horizontal line

        # For debugging, display the raw contents provided by the web browser
        html.Div('Raw Content'),
        html.Pre(contents[0:200] + '...', style={
            'whiteSpace': 'pre-wrap',
            'wordBreak': 'break-all'
        })
    ])                

offline_rohini = pd.read_csv('rohini_khola_2021.csv')
offline_bgau = pd.read_csv('banjare_gau_2021.csv')
offline_channawa = pd.read_csv('channawa_2021.csv')
offline_dgau = pd.read_csv('d_gau_2021.csv')
offline_jaispur = pd.read_csv('jaispur_2021.csv')
offline_kalhanshangau = pd.read_csv('kalhanshgau_2021.csv')
offline_khadaicha = pd.read_csv('khadaicha_2021.csv')
offline_piprahawa = pd.read_csv('piprahawa_2021.csv')
offline_shikanpurwa = pd.read_csv('shikanpurwa_2021.csv')
# print(f"{offline_rohini.columns}-------------------->")
offline_df = [offline_rohini, offline_bgau, offline_channawa, offline_dgau, offline_jaispur, offline_kalhanshangau, offline_khadaicha, offline_piprahawa, offline_shikanpurwa]
# print(offline_df_roh.columns)
location_column_offline = ['Rohini Khola','Banjare Gau', 'Channawa','D-Gau','Jaispur','Kalhanshangau','Khadaicha','Piprahawa','Shikanpurwa']
cols_rename = ['SN','Date','Abs Pres (KPa)','Temp(°C)','Water Level(meters)']

all_offline_data = {}
def offline_data_transform(df,renamed_columns):
    df = df.iloc[:,:5]
    df.columns = cols_rename
    df['Water Level(meters)'] = abs(df['Water Level(meters)'])
    df['Date'] = pd.to_datetime(df['Date'])
    df['Month'] = df['Date'].dt.month
    df['Month'] = df['Month'].apply(lambda x: calendar.month_abbr[x])

    df['Date'] = df['Date'].dt.date
    df['Location'] = location_column_offline[i]
    # df.groupby(['name', 'id', 'dept'])['total_sale'].mean().reset_index()

    df = df.groupby(['Location','Month'], as_index=False)['Water Level(meters)'].mean().reset_index()
    # print(df)
    # all_offline_data[i] = df
    # print(df)

# for i in range(len(offline_df)):
#     offline_data_transform(offline_df[i],cols_rename)

# all_off_logger_df = pd.concat([all_offline_data[0],all_offline_data[1],all_offline_data[2],all_offline_data[3],
# all_offline_data[4],all_offline_data[5],
# all_offline_data[6],all_offline_data[7],all_offline_data[8]])

# %%
import requests
from requests.auth import HTTPBasicAuth
import pandas as pd
import time, sched

import dash_html_components as html
import dash_core_components as dcc

import calendar
from urllib.parse import quote as urlquote

url= "https://kc.humanitarianresponse.info/api/v1/data/669773.json"
auth = HTTPBasicAuth('gw_monitoring', 'gwmonitor@2020')

import base64
import io
import datetime
import dash_table
import os
from os import path



# files = {'filename': open('filename.txt','rb')}
def download_data():
    download = requests.get(url, auth=auth )
    # col_names = ['Enumerator Name','Geo_location','Municipality','village_name','ward','well_type','well_no_stw','well_no_dtw','gw_level','Height_of_measurement','measurement_unit',"Notes"]
    # df = pd.read_csv('updated_data.csv')  
    j = requests.get(url, auth=auth )
    df_json = j.json()
    gw_df = pd.DataFrame.from_dict(df_json)
#     print(gw_df.columns)
#     print(len(gw_df.columns))  
    # 'sw_bk_well_no','bk_dw_no','well_no_sw_bardiya','well_no_dw_bardiya',
    if not 'Main_group/location_details/sw_bk_well_no' in gw_df.columns:
        #     print("NO cols_1")
            gw_df['sw_bk_well_no'] = '' 
    if not 'Main_group/location_details/bk_dw_no' in gw_df.columns:
        #     print("NO cols_2")
            gw_df['bk_dw_no'] = '' 
    
    if not 'Main_group/location_details/well_no_sw_bardiya' in gw_df.columns:
        #     print("NO cols_3")
            gw_df['well_no_sw_bardiya'] = '' 
    
    if not 'Main_group/location_details/well_no_dw_bardiya' in gw_df.columns:
            gw_df['well_no_dw_bardiya'] = '' 
        #     print("NO cols_4")
#     print(len(gw_df.columns))   
#     print(gw_df.columns)       
    # gw_df = pd.read_json(download.text)   
    if len(gw_df.columns) != 36:
        #     return html.Div([html.H1("ERROR: With fetching the data. Please check later")])
            df = pd.DataFrame()
        #     df = pd.read_csv('updated_data.csv')  
            print("ERROR")
    else:
        gw_df.columns = ['_notes',
       'Measurement_of_tape_ent_point_MP_in_m', '_tags',
       '_xform_id_string', 'meta/instanceID',
       'gw_level_from_mp', 'end',
       'gw_level',
       'Well_photo_Use_the_ed_measurement_point',
       'mp_in_m', 'start', '_attachments', '_version_',
       '_status', '__version__', 'today',
       'sw_bk_well_no',
       'Enumerator Name',
       'Geo_location', '_validation_status',
       '_uuid', 'well_type', 'formhub/uuid',
       'District', '_submission_time',
       '_geolocation', '_submitted_by',
       'wet_point_measruement_on_tape', 'deviceid',
       'measurement_point_cm', '_id',
       'Notes',
       'Audio_Notes',
       'well_no_sw_bardiya', 'bk_dw_no',
       'well_no_dw_bardiya']
        all_cols = ['Enumerator Name','Geo_location','District',
        'well_type','sw_bk_well_no','bk_dw_no','well_no_sw_bardiya','well_no_dw_bardiya','measurement_point_cm',
        'Measurement_of_tape_ent_point_MP_in_m', 'wet_point_measruement_on_tape','gw_level',
        'Notes','today','Audio_Notes']

        # print(gw_df)
        df = pd.DataFrame()
        
        for cols in all_cols:
                df[cols] = gw_df[cols]
        # df = gw_df.copy()  
        # print(df) 
        # df = df.sort_values(by='today')
        # print(df)
        # df['Enumerator']
            # print(gw_df[i])   
        df['well_no'] = (df['sw_bk_well_no'].combine_first(df['bk_dw_no']).combine_first(df['well_no_sw_bardiya']).combine_first(df['well_no_dw_bardiya']))
        ## onvertt he today data to date    
        df['today'] = pd.to_datetime(df['today'])
        df['Month'] = df['today'].dt.month
        # print(df['Month'])
        df['Month'] = df['Month'].apply(lambda x: calendar.month_abbr[x])   
        df.to_csv('updated_data.csv')
    return df 

gw_df = download_data()

# %%
gw_df
# Out:
#     Enumerator Name                                    Geo_location District  \
# 0          yogendra   28.0151149 81.6542853 86.65167613637765 4.854    Banke
# 1          yogendra  28.0020096 81.6522108 107.77393555615072 4.854    Banke
# 2          yogendra   28.0242741 81.6002787 89.81682168351188 4.854    Banke
# 3          yogendra   28.0780604 81.5932225 97.16194288745902 4.854    Banke
# 4         yogendral   28.1287297 81.5894124 88.46230121420037 4.854    Banke
# ..              ...                                             ...      ...
# 147           Anita  28.2795566 81.2628796 101.39670729066788 4.803  Bardiya
# 148           Anita  28.3287679 81.2715464 121.20034075891353 4.551  Bardiya
# 149           Anita   28.0731597 81.5542048 89.54488569715397 4.803  Bardiya
# 150           Anita   28.0730776 81.5542921 93.41935404156682 4.854  Bardiya
# 151           Anita      28.071498 81.5555033 83.979209134853 4.854  Bardiya
#
#     well_type sw_bk_well_no  bk_dw_no well_no_sw_bardiya well_no_dw_bardiya  \
# 0          sw    bk-sw-09_1       NaN                NaN                NaN
# 1          sw      bk-sw-29       NaN                NaN                NaN
# 2          sw    bk-sw-11_1       NaN                NaN                NaN
# 3          sw      bk-sw-26       NaN                NaN                NaN
# 4          sw    bk-sw-17_1       NaN                NaN                NaN
# ..        ...           ...       ...                ...                ...
# 147        sw           NaN  bd-sw-12                NaN                NaN
# 148        sw           NaN  bd-sw-13                NaN                NaN
# 149        sw           NaN  bd-sw-15                NaN                NaN
# 150        sw           NaN  bd-sw-14                NaN                NaN
# 151        sw           NaN  bd-sw-16                NaN                NaN
#
#     measurement_point_cm Measurement_of_tape_ent_point_MP_in_m  \
# 0                     60                                   5.0
# 1                     40                                   6.0
# 2                     50                                   7.0
# 3                     25                                   5.0
# 4                     15                                   5.0
# ..                   ...                                   ...
# 147                   40                                  14.0
# 148                   10                                   5.0
# 149                   55                                   4.0
# 150                   10                                   4.0
# 151                   60                                   5.0
#
#     wet_point_measruement_on_tape gw_level Notes      today Audio_Notes  \
# 0                            2.02     2.38   NaN 2021-02-22         NaN
# 1                             1.5      4.1   NaN 2021-02-22         NaN
# 2                            1.82     4.68   NaN 2021-02-22         NaN
# 3                            2.31     2.44   NaN 2021-02-20         NaN
# 4                            1.78     3.07   NaN 2021-02-20         NaN
# ..                            ...      ...   ...        ...         ...
# 147                           2.0     11.6   NaN 2021-04-04         NaN
# 148                           1.8      3.1   NaN 2021-04-04         NaN
# 149                           1.0     2.45   NaN 2021-04-06         NaN
# 150                           1.5      2.4   NaN 2021-04-06         NaN
# 151                           1.0      3.4   NaN 2021-04-07         NaN
#
#         well_no Month
# 0    bk-sw-09_1   Feb
# 1      bk-sw-29   Feb
# 2    bk-sw-11_1   Feb
# 3      bk-sw-26   Feb
# 4    bk-sw-17_1   Feb
# ..          ...   ...
# 147    bd-sw-12   Apr
# 148    bd-sw-13   Apr
# 149    bd-sw-15   Apr
# 150    bd-sw-14   Apr
# 151    bd-sw-16   Apr
#
# [152 rows x 17 columns]

# %%
banke_sw = gw_df[(gw_df['District']=="Banke") & (gw_df['well_type'] == 'sw')]
banke_sw= banke_sw[['Enumerator Name','Geo_location','District',
        'well_type','sw_bk_well_no','gw_level',
        'measurement_point_cm',
        'Measurement_of_tape_ent_point_MP_in_m',
        'Notes']]
banke_sw
# Out:
#     Enumerator Name                                    Geo_location District  \
# 0          yogendra   28.0151149 81.6542853 86.65167613637765 4.854    Banke
# 1          yogendra  28.0020096 81.6522108 107.77393555615072 4.854    Banke
# 2          yogendra   28.0242741 81.6002787 89.81682168351188 4.854    Banke
# 3          yogendra   28.0780604 81.5932225 97.16194288745902 4.854    Banke
# 4         yogendral   28.1287297 81.5894124 88.46230121420037 4.854    Banke
# ..              ...                                             ...      ...
# 123        yogendra   28.1287337 81.5893729 87.98446775075215 4.551    Banke
# 124        yogendra   28.1465581 81.5519536 103.6786630334175 4.551    Banke
# 125        yogendra   28.1317973 81.6588377 98.44866010861558 4.803    Banke
# 126        yogendra   28.0928489 81.6478628 94.33627246343464 4.854    Banke
# 127        yogendra   28.0812185 81.645044 101.03061213006376 4.803    Banke
#
#     well_type sw_bk_well_no gw_level measurement_point_cm  \
# 0          sw    bk-sw-09_1     2.38                   60
# 1          sw      bk-sw-29      4.1                   40
# 2          sw    bk-sw-11_1     4.68                   50
# 3          sw      bk-sw-26     2.44                   25
# 4          sw    bk-sw-17_1     3.07                   15
# ..        ...           ...      ...                  ...
# 123        sw    bk-sw-17_1      3.8                   15
# 124        sw    bk-sw-18_1     3.65                   27
# 125        sw    bk-sw-06_1     2.29                   45
# 126        sw    bk-sw-07_1      4.3                   15
# 127        sw    bk-sw-24_1     3.91                   54
#
#     Measurement_of_tape_ent_point_MP_in_m Notes
# 0                                     5.0   NaN
# 1                                     6.0   NaN
# 2                                     7.0   NaN
# 3                                     5.0   NaN
# 4                                     5.0   NaN
# ..                                    ...   ...
# 123                                   5.0   NaN
# 124                                   5.0   NaN
# 125                                   5.0   NaN
# 126                                  4.95   NaN
# 127                                   6.0   NaN
#
# [62 rows x 9 columns]

# %%
d = dash_table.DataTable(
    id='live_table',
    columns=[{"name": i, "id": i} for i in banke_sw],
     style_cell={
      
        'height': 'auto',
        # all three widths are needed
        'minWidth': '180px', 'width': '180px', 'maxWidth': '180px',
        'whiteSpace': 'normal'
         
    },
    style_table={'overflowX': 'auto','height': '500px', 'overflowY': 'auto'},
#    data=table.to_dict('records'),
   
    export_format="csv",
)

d.plot
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-9-faf31a64ca4b> in <module>
#      16 )
#      17
# ---> 18 d.plot
#
# AttributeError: 'DataTable' object has no attribute 'plot'

# %%
banke_sw.to_dict('records')
# Out:
# [{'Enumerator Name': 'yogendra',
#   'Geo_location': '28.0151149 81.6542853 86.65167613637765 4.854',
#   'District': 'Banke',
#   'well_type': 'sw',
#   'sw_bk_well_no': 'bk-sw-09_1',
#   'gw_level': '2.38',
#   'measurement_point_cm': '60',
#   'Measurement_of_tape_ent_point_MP_in_m': '5.0',
#   'Notes': nan},
#  {'Enumerator Name': 'yogendra',
#   'Geo_location': '28.0020096 81.6522108 107.77393555615072 4.854',
#   'District': 'Banke',
#   'well_type': 'sw',
#   'sw_bk_well_no': 'bk-sw-29',
#   'gw_level': '4.1',
#   'measurement_point_cm': '40',
#   'Measurement_of_tape_ent_point_MP_in_m': '6.0',
#   'Notes': nan},
#  {'Enumerator Name': 'yogendra',
#   'Geo_location': '28.0242741 81.6002787 89.81682168351188 4.854',
#   'District': 'Banke',
#   'well_type': 'sw',
#   'sw_bk_well_no': 'bk-sw-11_1',
#   'gw_level': '4.68',
#   'measurement_point_cm': '50',
#   'Measurement_of_tape_ent_point_MP_in_m': '7.0',
#   'Notes': nan},
#  {'Enumerator Name': 'yogendra',
#   'Geo_location': '28.0780604 81.5932225 97.16194288745902 4.854',
#   'District': 'Banke',
#   'well_type': 'sw',
#   'sw_bk_well_no': 'bk-sw-26',
#   'gw_level': '2.44',
#   'measurement_point_cm': '25',
#   'Measurement_of_tape_ent_point_MP_in_m': '5.0',
#   'Notes': nan},
#  {'Enumerator Name': 'yogendral',
#   'Geo_location': '28.1287297 81.5894124 88.46230121420037 4.854',
#   'District': 'Banke',
#   'well_type': 'sw',
#   'sw_bk_well_no': 'bk-sw-17_1',
#   'gw_level': '3.07',
#   'measurement_point_cm': '15',
#   'Measurement_of_tape_ent_point_MP_in_m': '5.0',
#   'Notes': nan},
#  {'Enumerator Name': 'yogendra',
#   'Geo_location': '28.1114016 81.521705 61.428869979187425 4.551',
#   'District': 'Banke',
#   'well_type': 'sw',
#   'sw_bk_well_no': 'bk-sw-19_1',
#   'gw_level': '5.62',
#   'measurement_point_cm': '23',
#   'Measurement_of_tape_ent_point_MP_in_m': '7.0',
#   'Notes': nan},
#  {'Enumerator Name': 'yogendra',
#   'Geo_location': '28.0508057 81.5862265 87.09753899548474 4.803',
#   'District': 'Banke',
#   'well_type': 'sw',
#   'sw_bk_well_no': 'bk-sw-28',
#   'gw_level': '4.95',
#   'measurement_point_cm': '55',
#   'Measurement_of_tape_ent_point_MP_in_m': '7.0',
#   'Notes': nan},
#  {'Enumerator Name': 'yogndra',
#   'Geo_location': '28.0780663 81.5933074 94.0 4.854',
#   'District': 'Banke',
#   'well_type': 'sw',
#   'sw_bk_well_no': 'bk-sw-26',
#   'gw_level': '2.2',
#   'measurement_point_cm': '25',
#   'Measurement_of_tape_ent_point_MP_in_m': '5.0',
#   'Notes': nan},
#  {'Enumerator Name': 'Subash',
#   'Geo_location': '28.0804943 81.6419293 114.0 13.349',
#   'District': 'Banke',
#   'well_type': 'sw',
#   'sw_bk_well_no': 'bk-sw-01',
#   'gw_level': '2.2',
#   'measurement_point_cm': '20',
#   'Measurement_of_tape_ent_point_MP_in_m': '3.6',
#   'Notes': nan},
#  {'Enumerator Name': 'yogendra',
#   'Geo_location': '28.0828437 81.5956795 92.0 4.551',
#   'District': 'Banke',
#   'well_type': 'sw',
#   'sw_bk_well_no': 'bk-sw-27',
#   'gw_level': '3.7',
#   'measurement_point_cm': '40',
#   'Measurement_of_tape_ent_point_MP_in_m': '4.6',
#   'Notes': nan},
#  {'Enumerator Name': 'yogendra',
#   'Geo_location': '28.1060386 81.5971551 99.0 4.551',
#   'District': 'Banke',
#   'well_type': 'sw',
#   'sw_bk_well_no': 'bk-sw-25_1',
#   'gw_level': '2.9',
#   'measurement_point_cm': '35',
#   'Measurement_of_tape_ent_point_MP_in_m': '3.75',
#   'Notes': nan},
#  {'Enumerator Name': 'yogendra',
#   'Geo_location': '28.1287151 81.5894281 88.0 4.551',
#   'District': 'Banke',
#   'well_type': 'sw',
#   'sw_bk_well_no': 'bk-sw-17_1',
#   'gw_level': '2.7',
#   'measurement_point_cm': '15',
#   'Measurement_of_tape_ent_point_MP_in_m': '5.0',
#   'Notes': nan},
#  {'Enumerator Name': 'yogendra',
#   'Geo_location': '28.1465454 81.5519862 93.0 4.551',
#   'District': 'Banke',
#   'well_type': 'sw',
#   'sw_bk_well_no': 'bk-sw-18_1',
#   'gw_level': '2.68',
#   'measurement_point_cm': '27',
#   'Measurement_of_tape_ent_point_MP_in_m': '5.0',
#   'Notes': nan},
#  {'Enumerator Name': 'yogendra',
#   'Geo_location': '28.1114479 81.5216935 79.0 4.551',
#   'District': 'Banke',
#   'well_type': 'sw',
#   'sw_bk_well_no': 'bk-sw-19_1',
#   'gw_level': '4.72',
#   'measurement_point_cm': '23',
#   'Measurement_of_tape_ent_point_MP_in_m': '7.0',
#   'Notes': nan},
#  {'Enumerator Name': 'yogendra',
#   'Geo_location': '28.1920455 81.5747481 99.0 4.854',
#   'District': 'Banke',
#   'well_type': 'sw',
#   'sw_bk_well_no': 'bk-sw-05_1',
#   'gw_level': '2.96',
#   'measurement_point_cm': '29',
#   'Measurement_of_tape_ent_point_MP_in_m': '5.0',
#   'Notes': nan},
#  {'Enumerator Name': 'yogendra',
#   'Geo_location': '28.2576903 81.6361819 95.0 4.551',
#   'District': 'Banke',
#   'well_type': 'sw',
#   'sw_bk_well_no': 'bk-sw-02',
#   'gw_level': '-0.15',
#   'measurement_point_cm': '15',
#   'Measurement_of_tape_ent_point_MP_in_m': '0.0',
#   'Notes': nan},
#  {'Enumerator Name': 'yogendra',
#   'Geo_location': '28.2064949 81.6307264 101.0 4.803',
#   'District': 'Banke',
#   'well_type': 'sw',
#   'sw_bk_well_no': 'bk-sw-03',
#   'gw_level': '6.1',
#   'measurement_point_cm': '40',
#   'Measurement_of_tape_ent_point_MP_in_m': '8.0',
#   'Notes': nan},
#  {'Enumerator Name': 'yogendra',
#   'Geo_location': '28.0493274 81.6616258 95.0 4.551',
#   'District': 'Banke',
#   'well_type': 'sw',
#   'sw_bk_well_no': 'bk-sw-08_1',
#   'gw_level': '5.49',
#   'measurement_point_cm': '36',
#   'Measurement_of_tape_ent_point_MP_in_m': '8.0',
#   'Notes': nan},
#  {'Enumerator Name': 'yogendra',
#   'Geo_location': '28.0285434 81.6946848 78.0 4.854',
#   'District': 'Banke',
#   'well_type': 'sw',
#   'sw_bk_well_no': 'bk-sw-30',
#   'gw_level': '3.9',
#   'measurement_point_cm': '55',
#   'Measurement_of_tape_ent_point_MP_in_m': '6.0',
#   'Notes': nan},
#  {'Enumerator Name': 'yogendra',
#   'Geo_location': '27.9833039 81.7132923 84.0 4.551',
#   'District': 'Banke',
#   'well_type': 'sw',
#   'sw_bk_well_no': 'bk-sw-10_1',
#   'gw_level': '2.75',
#   'measurement_point_cm': '70',
#   'Measurement_of_tape_ent_point_MP_in_m': '5.0',
#   'Notes': nan},
#  {'Enumerator Name': 'yogendra',
#   'Geo_location': '28.0507443 81.5861794 89.0 4.854',
#   'District': 'Banke',
#   'well_type': 'sw',
#   'sw_bk_well_no': 'bk-sw-28',
#   'gw_level': '4.3',
#   'measurement_point_cm': '55',
#   'Measurement_of_tape_ent_point_MP_in_m': '6.0',
#   'Notes': nan},
#  {'Enumerator Name': 'yogendra',
#   'Geo_location': '28.0242587 81.6002836 91.0 4.854',
#   'District': 'Banke',
#   'well_type': 'sw',
#   'sw_bk_well_no': 'bk-sw-11_1',
#   'gw_level': '4.15',
#   'measurement_point_cm': '50',
#   'Measurement_of_tape_ent_point_MP_in_m': '6.0',
#   'Notes': nan},
#  {'Enumerator Name': 'yogendra',
#   'Geo_location': '28.0151183 81.6543479 82.0 4.803',
#   'District': 'Banke',
#   'well_type': 'sw',
#   'sw_bk_well_no': 'bk-sw-09_1',
#   'gw_level': '2.15',
#   'measurement_point_cm': '60',
#   'Measurement_of_tape_ent_point_MP_in_m': '5.0',
#   'Notes': nan},
#  {'Enumerator Name': 'yogendra',
#   'Geo_location': '28.0020439 81.6523786 69.0 4.551',
#   'District': 'Banke',
#   'well_type': 'sw',
#   'sw_bk_well_no': 'bk-sw-29',
#   'gw_level': '3.9',
#   'measurement_point_cm': '40',
#   'Measurement_of_tape_ent_point_MP_in_m': '6.0',
#   'Notes': nan},
#  {'Enumerator Name': 'yogendra',
#   'Geo_location': '28.1873921 81.6300983 105.0 4.551',
#   'District': 'Banke',
#   'well_type': 'sw',
#   'sw_bk_well_no': 'bk-sw-04',
#   'gw_level': '1.7',
#   'measurement_point_cm': '65',
#   'Measurement_of_tape_ent_point_MP_in_m': '5.0',
#   'Notes': nan},
#  {'Enumerator Name': 'yogendra',
#   'Geo_location': '28.1960977 81.7117444 107.0 4.551',
#   'District': 'Banke',
#   'well_type': 'sw',
#   'sw_bk_well_no': 'bk-sw-01',
#   'gw_level': '2.95',
#   'measurement_point_cm': '20',
#   'Measurement_of_tape_ent_point_MP_in_m': '5.0',
#   'Notes': nan},
#  {'Enumerator Name': 'yogendra',
#   'Geo_location': '28.0812224 81.6450643 94.0 4.551',
#   'District': 'Banke',
#   'well_type': 'sw',
#   'sw_bk_well_no': 'bk-sw-24_1',
#   'gw_level': '3.01',
#   'measurement_point_cm': '54',
#   'Measurement_of_tape_ent_point_MP_in_m': '6.0',
#   'Notes': nan},
#  {'Enumerator Name': 'yogendra',
#   'Geo_location': '28.0928582 81.6478693 99.0 4.551',
#   'District': 'Banke',
#   'well_type': 'sw',
#   'sw_bk_well_no': 'bk-sw-07_1',
#   'gw_level': '3.5',
#   'measurement_point_cm': '15',
#   'Measurement_of_tape_ent_point_MP_in_m': '4.15',
#   'Notes': nan},
#  {'Enumerator Name': 'yogendra',
#   'Geo_location': '28.13181 81.6588146 97.0 4.854',
#   'District': 'Banke',
#   'well_type': 'sw',
#   'sw_bk_well_no': 'bk-sw-06_1',
#   'gw_level': '1.75',
#   'measurement_point_cm': '45',
#   'Measurement_of_tape_ent_point_MP_in_m': '5.0',
#   'Notes': nan},
#  {'Enumerator Name': 'yogendra',
#   'Geo_location': '28.0507648 81.5861597 99.08832275188804 4.551',
#   'District': 'Banke',
#   'well_type': 'sw',
#   'sw_bk_well_no': 'bk-sw-28',
#   'gw_level': '4.6',
#   'measurement_point_cm': '55',
#   'Measurement_of_tape_ent_point_MP_in_m': '7.0',
#   'Notes': nan},
#  {'Enumerator Name': 'yogendra',
#   'Geo_location': '28.1318094 81.6588648 108.93264494159047 4.551',
#   'District': 'Banke',
#   'well_type': 'sw',
#   'sw_bk_well_no': 'bk-sw-06_1',
#   'gw_level': '1.9',
#   'measurement_point_cm': '45',
#   'Measurement_of_tape_ent_point_MP_in_m': '5.0',
#   'Notes': nan},
#  {'Enumerator Name': 'yogendra',
#   'Geo_location': '28.0928569 81.6478714 101.68621225168131 4.551',
#   'District': 'Banke',
#   'well_type': 'sw',
#   'sw_bk_well_no': 'bk-sw-07_1',
#   'gw_level': '3.7',
#   'measurement_point_cm': '15',
#   'Measurement_of_tape_ent_point_MP_in_m': '4.35',
#   'Notes': nan},
#  {'Enumerator Name': 'yogendra',
#   'Geo_location': '28.0812296 81.6450593 107.35515950953524 4.551',
#   'District': 'Banke',
#   'well_type': 'sw',
#   'sw_bk_well_no': 'bk-sw-24_1',
#   'gw_level': '3.51',
#   'measurement_point_cm': '54',
#   'Measurement_of_tape_ent_point_MP_in_m': '6.0',
#   'Notes': nan},
#  {'Enumerator Name': 'yogendra',
#   'Geo_location': '28.1961034 81.711776 118.65058920259087 4.854',
#   'District': 'Banke',
#   'well_type': 'sw',
#   'sw_bk_well_no': 'bk-sw-01',
#   'gw_level': '3.3',
#   'measurement_point_cm': '20',
#   'Measurement_of_tape_ent_point_MP_in_m': '5.0',
#   'Notes': nan},
#  {'Enumerator Name': 'yogendra',
#   'Geo_location': '28.1465538 81.5519786 99.09388732335618 4.551',
#   'District': 'Banke',
#   'well_type': 'sw',
#   'sw_bk_well_no': 'bk-sw-18_1',
#   'gw_level': '3.13',
#   'measurement_point_cm': '27',
#   'Measurement_of_tape_ent_point_MP_in_m': '5.0',
#   'Notes': nan},
#  {'Enumerator Name': 'yogendra',
#   'Geo_location': '28.206544 81.6307359 111.39332472668187 4.803',
#   'District': 'Banke',
#   'well_type': 'sw',
#   'sw_bk_well_no': 'bk-sw-03',
#   'gw_level': '6.3',
#   'measurement_point_cm': '40',
#   'Measurement_of_tape_ent_point_MP_in_m': '9.0',
#   'Notes': nan},
#  {'Enumerator Name': 'yogendra',
#   'Geo_location': '28.1921073 81.5747382 93.94653314024943 4.803',
#   'District': 'Banke',
#   'well_type': 'sw',
#   'sw_bk_well_no': 'bk-sw-05_1',
#   'gw_level': '3.01',
#   'measurement_point_cm': '29',
#   'Measurement_of_tape_ent_point_MP_in_m': '5.0',
#   'Notes': nan},
#  {'Enumerator Name': 'yogendra',
#   'Geo_location': '28.1873729 81.630073 120.06170870396069 4.854',
#   'District': 'Banke',
#   'well_type': 'sw',
#   'sw_bk_well_no': 'bk-sw-04',
#   'gw_level': '1.83',
#   'measurement_point_cm': '65',
#   'Measurement_of_tape_ent_point_MP_in_m': '5.0',
#   'Notes': nan},
#  {'Enumerator Name': 'yogendra',
#   'Geo_location': '28.0830308 81.5956368 104.12210698051976 4.551',
#   'District': 'Banke',
#   'well_type': 'sw',
#   'sw_bk_well_no': 'bk-sw-27',
#   'gw_level': '3.9',
#   'measurement_point_cm': '40',
#   'Measurement_of_tape_ent_point_MP_in_m': '4.8',
#   'Notes': nan},
#  {'Enumerator Name': 'yogendra',
#   'Geo_location': '28.1060812 81.5971233 104.21288580035973 4.551',
#   'District': 'Banke',
#   'well_type': 'sw',
#   'sw_bk_well_no': 'bk-sw-25_1',
#   'gw_level': '3.05',
#   'measurement_point_cm': '35',
#   'Measurement_of_tape_ent_point_MP_in_m': '3.9',
#   'Notes': nan},
#  {'Enumerator Name': 'yogendra',
#   'Geo_location': '28.1114455 81.5216505 96.5277953917899 4.854',
#   'District': 'Banke',
#   'well_type': 'sw',
#   'sw_bk_well_no': 'bk-sw-19_1',
#   'gw_level': '5.27',
#   'measurement_point_cm': '23',
#   'Measurement_of_tape_ent_point_MP_in_m': '7.0',
#   'Notes': nan},
#  {'Enumerator Name': 'yogendra',
#   'Geo_location': '28.0494204 81.6616308 95.60796911318198 4.551',
#   'District': 'Banke',
#   'well_type': 'sw',
#   'sw_bk_well_no': 'bk-sw-08_1',
#   'gw_level': '5.99',
#   'measurement_point_cm': '36',
#   'Measurement_of_tape_ent_point_MP_in_m': '8.0',
#   'Notes': nan},
#  {'Enumerator Name': 'yogendra',
#   'Geo_location': '28.0285545 81.6946709 100.51913615300215 4.551',
#   'District': 'Banke',
#   'well_type': 'sw',
#   'sw_bk_well_no': 'bk-sw-30',
#   'gw_level': '4.15',
#   'measurement_point_cm': '55',
#   'Measurement_of_tape_ent_point_MP_in_m': '6.0',
#   'Notes': nan},
#  {'Enumerator Name': 'yogendra',
#   'Geo_location': '27.9834125 81.7133541 89.83573954444914 4.803',
#   'District': 'Banke',
#   'well_type': 'sw',
#   'sw_bk_well_no': 'bk-sw-10_1',
#   'gw_level': '2.97',
#   'measurement_point_cm': '70',
#   'Measurement_of_tape_ent_point_MP_in_m': '5.0',
#   'Notes': nan},
#  {'Enumerator Name': 'yogendra',
#   'Geo_location': '28.0243004 81.6002834 85.53872048691571 4.551',
#   'District': 'Banke',
#   'well_type': 'sw',
#   'sw_bk_well_no': 'bk-sw-11_1',
#   'gw_level': '4.9',
#   'measurement_point_cm': '50',
#   'Measurement_of_tape_ent_point_MP_in_m': '7.0',
#   'Notes': nan},
#  {'Enumerator Name': 'yogendra',
#   'Geo_location': '28.0150979 81.6543421 79.45554699138219 4.854',
#   'District': 'Banke',
#   'well_type': 'sw',
#   'sw_bk_well_no': 'bk-sw-09_1',
#   'gw_level': '2.6',
#   'measurement_point_cm': '60',
#   'Measurement_of_tape_ent_point_MP_in_m': '5.0',
#   'Notes': nan},
#  {'Enumerator Name': 'yogendra',
#   'Geo_location': '28.002087 81.652334 74.79502092410074 4.803',
#   'District': 'Banke',
#   'well_type': 'sw',
#   'sw_bk_well_no': 'bk-sw-29',
#   'gw_level': '4.55',
#   'measurement_point_cm': '40',
#   'Measurement_of_tape_ent_point_MP_in_m': '7.0',
#   'Notes': nan},
#  {'Enumerator Name': 'yogendra',
#   'Geo_location': '28.0285641 81.6947339 83.35339274716405 4.854',
#   'District': 'Banke',
#   'well_type': 'sw',
#   'sw_bk_well_no': 'bk-sw-30',
#   'gw_level': '4.3',
#   'measurement_point_cm': '55',
#   'Measurement_of_tape_ent_point_MP_in_m': '6.0',
#   'Notes': nan},
#  {'Enumerator Name': 'yogendra',
#   'Geo_location': '27.98343 81.713307 73.34943673778383 4.551',
#   'District': 'Banke',
#   'well_type': 'sw',
#   'sw_bk_well_no': 'bk-sw-10_1',
#   'gw_level': '3.07',
#   'measurement_point_cm': '70',
#   'Measurement_of_tape_ent_point_MP_in_m': '5.0',
#   'Notes': nan},
#  {'Enumerator Name': 'yogendra',
#   'Geo_location': '28.0493765 81.6617097 93.93173480873038 4.551',
#   'District': 'Banke',
#   'well_type': 'sw',
#   'sw_bk_well_no': 'bk-sw-08_1',
#   'gw_level': '6.14',
#   'measurement_point_cm': '36',
#   'Measurement_of_tape_ent_point_MP_in_m': '8.0',
#   'Notes': nan},
#  {'Enumerator Name': 'yogendra',
#   'Geo_location': '28.1960804 81.7117424 127.62967228481328 4.854',
#   'District': 'Banke',
#   'well_type': 'sw',
#   'sw_bk_well_no': 'bk-sw-01',
#   'gw_level': '3.46',
#   'measurement_point_cm': '20',
#   'Measurement_of_tape_ent_point_MP_in_m': '5.0',
#   'Notes': nan},
#  {'Enumerator Name': 'yogendra',
#   'Geo_location': '28.206532 81.6306905 107.15215606637075 4.803',
#   'District': 'Banke',
#   'well_type': 'sw',
#   'sw_bk_well_no': 'bk-sw-03',
#   'gw_level': '6.85',
#   'measurement_point_cm': '40',
#   'Measurement_of_tape_ent_point_MP_in_m': '9.0',
#   'Notes': nan},
#  {'Enumerator Name': 'yogendra',
#   'Geo_location': '28.1920742 81.5747772 89.91490084008717 4.551',
#   'District': 'Banke',
#   'well_type': 'sw',
#   'sw_bk_well_no': 'bk-sw-05_1',
#   'gw_level': '3.11',
#   'measurement_point_cm': '29',
#   'Measurement_of_tape_ent_point_MP_in_m': '5.0',
#   'Notes': nan},
#  {'Enumerator Name': 'yogendra',
#   'Geo_location': '28.1873992 81.6299874 104.63128751372183 4.551',
#   'District': 'Banke',
#   'well_type': 'sw',
#   'sw_bk_well_no': 'bk-sw-04',
#   'gw_level': '2.28',
#   'measurement_point_cm': '65',
#   'Measurement_of_tape_ent_point_MP_in_m': '5.0',
#   'Notes': nan},
#  {'Enumerator Name': 'yogendra',
#   'Geo_location': '28.078045 81.5932275 84.9956152614164 4.854',
#   'District': 'Banke',
#   'well_type': 'sw',
#   'sw_bk_well_no': 'bk-sw-26',
#   'gw_level': '2.83',
#   'measurement_point_cm': '25',
#   'Measurement_of_tape_ent_point_MP_in_m': '5.0',
#   'Notes': nan},
#  {'Enumerator Name': 'yogendra',
#   'Geo_location': '28.0830206 81.5956341 76.27681261735586 4.803',
#   'District': 'Banke',
#   'well_type': 'sw',
#   'sw_bk_well_no': 'bk-sw-27',
#   'gw_level': '4',
#   'measurement_point_cm': '40',
#   'Measurement_of_tape_ent_point_MP_in_m': '4.9',
#   'Notes': nan},
#  {'Enumerator Name': 'yogendra',
#   'Geo_location': '28.1060287 81.5971035 84.74134994144606 4.551',
#   'District': 'Banke',
#   'well_type': 'sw',
#   'sw_bk_well_no': 'bk-sw-25_1',
#   'gw_level': '3.25',
#   'measurement_point_cm': '35',
#   'Measurement_of_tape_ent_point_MP_in_m': '4.1',
#   'Notes': nan},
#  {'Enumerator Name': 'yogendra',
#   'Geo_location': '28.1287337 81.5893729 87.98446775075215 4.551',
#   'District': 'Banke',
#   'well_type': 'sw',
#   'sw_bk_well_no': 'bk-sw-17_1',
#   'gw_level': '3.8',
#   'measurement_point_cm': '15',
#   'Measurement_of_tape_ent_point_MP_in_m': '5.0',
#   'Notes': nan},
#  {'Enumerator Name': 'yogendra',
#   'Geo_location': '28.1465581 81.5519536 103.6786630334175 4.551',
#   'District': 'Banke',
#   'well_type': 'sw',
#   'sw_bk_well_no': 'bk-sw-18_1',
#   'gw_level': '3.65',
#   'measurement_point_cm': '27',
#   'Measurement_of_tape_ent_point_MP_in_m': '5.0',
#   'Notes': nan},
#  {'Enumerator Name': 'yogendra',
#   'Geo_location': '28.1317973 81.6588377 98.44866010861558 4.803',
#   'District': 'Banke',
#   'well_type': 'sw',
#   'sw_bk_well_no': 'bk-sw-06_1',
#   'gw_level': '2.29',
#   'measurement_point_cm': '45',
#   'Measurement_of_tape_ent_point_MP_in_m': '5.0',
#   'Notes': nan},
#  {'Enumerator Name': 'yogendra',
#   'Geo_location': '28.0928489 81.6478628 94.33627246343464 4.854',
#   'District': 'Banke',
#   'well_type': 'sw',
#   'sw_bk_well_no': 'bk-sw-07_1',
#   'gw_level': '4.3',
#   'measurement_point_cm': '15',
#   'Measurement_of_tape_ent_point_MP_in_m': '4.95',
#   'Notes': nan},
#  {'Enumerator Name': 'yogendra',
#   'Geo_location': '28.0812185 81.645044 101.03061213006376 4.803',
#   'District': 'Banke',
#   'well_type': 'sw',
#   'sw_bk_well_no': 'bk-sw-24_1',
#   'gw_level': '3.91',
#   'measurement_point_cm': '54',
#   'Measurement_of_tape_ent_point_MP_in_m': '6.0',
#   'Notes': nan}]
